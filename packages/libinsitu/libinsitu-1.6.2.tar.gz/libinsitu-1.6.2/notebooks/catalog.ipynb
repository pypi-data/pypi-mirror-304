# %% [markdown]
# # Browsing a catalog and downloading data with Siphon
#
# This notebook demonstrates how to browse a Thredds catalog with [Siphon](https://unidata.github.io/siphon/latest/index.html) and download the data with [wget](https://pypi.org/project/wget/) or load it in memory (as Dataframes) with [Libinsitu](http://www.libinsitu.org/).

# %%
import os

from siphon.catalog import TDSCatalog
from wget import download 
from siphon.http_util import session_manager
from dotenv import load_dotenv
from libinsitu import netcdf_to_dataframe

# %%
# Optional : load and setup credentials from .env 

#load_dotenv()
#USER = os.environ["TDS_USER"]
#PASS = os.environ["TDS_PASS"]
#session_manager.set_session_options(auth=(USER, PASS))

# %%
# Read Catalog XML
cat = TDSCatalog('http://tds.webservice-energy.org/thredds/catalog/iea-pvps/catalog.xml')

# %%
# Loop on dataset
dataframes = dict()
for name, ds in cat.datasets.items():
    
    # Skip index
    if name == "index.nc" :
        continue
    
    # Download & file URLs
    file_url = ds.access_urls["File download"]
    odap_url = ds.access_urls["OPENDAP"]
    
    print("Dataset : %s" % name)
    print("Download URL", file_url)
    print("ODAP URL", odap_url)
    
    # Download the file
    download(file_url)
    
    # Alternatively you may read directly in memory via OpenDAP 
    # Warning : this may take a lot of memory
    # dataframes[name] = netcdf_to_dataframe(odap_url)
# Out:
# Dataset : IEA_PVPS-WIN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-WIN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-WIN.nc
# Dataset : IEA_PVPS-VUW.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-VUW.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-VUW.nc
# Dataset : IEA_PVPS-VIS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-VIS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-VIS.nc
# Dataset : IEA_PVPS-VAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-VAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-VAN.nc
# Dataset : IEA_PVPS-UML.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-UML.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-UML.nc
# Dataset : IEA_PVPS-TRI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TRI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TRI.nc
# Dataset : IEA_PVPS-TOR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TOR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TOR.nc
# Dataset : IEA_PVPS-TIR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TIR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TIR.nc
# Dataset : IEA_PVPS-TIK.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TIK.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TIK.nc
# Dataset : IEA_PVPS-TAT.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TAT.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TAT.nc
# Dataset : IEA_PVPS-TAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TAN.nc
# Dataset : IEA_PVPS-TAM.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TAM.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TAM.nc
# Dataset : IEA_PVPS-TAB.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-TAB.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-TAB.nc
# Dataset : IEA_PVPS-SYO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SYO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SYO.nc
# Dataset : IEA_PVPS-STE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-STE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-STE.nc
# Dataset : IEA_PVPS-SRR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SRR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SRR.nc
# Dataset : IEA_PVPS-SON.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SON.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SON.nc
# Dataset : IEA_PVPS-SOL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SOL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SOL.nc
# Dataset : IEA_PVPS-SIO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SIO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SIO.nc
# Dataset : IEA_PVPS-SEN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SEN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SEN.nc
# Dataset : IEA_PVPS-SAP.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SAP.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SAP.nc
# Dataset : IEA_PVPS-SAO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-SAO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-SAO.nc
# Dataset : IEA_PVPS-ROS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ROS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ROS.nc
# Dataset : IEA_PVPS-QUE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-QUE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-QUE.nc
# Dataset : IEA_PVPS-PRT.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PRT.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PRT.nc
# Dataset : IEA_PVPS-PRE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PRE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PRE.nc
# Dataset : IEA_PVPS-POR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-POR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-POR.nc
# Dataset : IEA_PVPS-PHI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PHI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PHI.nc
# Dataset : IEA_PVPS-PET.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PET.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PET.nc
# Dataset : IEA_PVPS-PES.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PES.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PES.nc
# Dataset : IEA_PVPS-PAY.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PAY.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PAY.nc
# Dataset : IEA_PVPS-PAR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PAR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PAR.nc
# Dataset : IEA_PVPS-PAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PAN.nc
# Dataset : IEA_PVPS-PAL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-PAL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-PAL.nc
# Dataset : IEA_PVPS-OUJ.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-OUJ.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-OUJ.nc
# Dataset : IEA_PVPS-ORE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ORE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ORE.nc
# Dataset : IEA_PVPS-OAK.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-OAK.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-OAK.nc
# Dataset : IEA_PVPS-NYA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-NYA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-NYA.nc
# Dataset : IEA_PVPS-NOR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-NOR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-NOR.nc
# Dataset : IEA_PVPS-NEU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-NEU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-NEU.nc
# Dataset : IEA_PVPS-NAT.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-NAT.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-NAT.nc
# Dataset : IEA_PVPS-MZU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MZU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MZU.nc
# Dataset : IEA_PVPS-MUT.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MUT.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MUT.nc
# Dataset : IEA_PVPS-MUR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MUR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MUR.nc
# Dataset : IEA_PVPS-MUL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MUL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MUL.nc
# Dataset : IEA_PVPS-MLE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MLE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MLE.nc
# Dataset : IEA_PVPS-MIY.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MIY.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MIY.nc
# Dataset : IEA_PVPS-MIS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MIS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MIS.nc
# Dataset : IEA_PVPS-MIN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MIN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MIN.nc
# Dataset : IEA_PVPS-MIL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MIL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MIL.nc
# Dataset : IEA_PVPS-MAR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-MAR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-MAR.nc
# Dataset : IEA_PVPS-LUS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LUS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LUS.nc
# Dataset : IEA_PVPS-LOY.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LOY.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LOY.nc
# Dataset : IEA_PVPS-LAU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LAU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LAU.nc
# Dataset : IEA_PVPS-LAS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LAS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LAS.nc
# Dataset : IEA_PVPS-LAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LAN.nc
# Dataset : IEA_PVPS-LAH.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-LAH.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-LAH.nc
# Dataset : IEA_PVPS-KWA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KWA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KWA.nc
# Dataset : IEA_PVPS-KIR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KIR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KIR.nc
# Dataset : IEA_PVPS-KHU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KHU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KHU.nc
# Dataset : IEA_PVPS-KDO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KDO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KDO.nc
# Dataset : IEA_PVPS-KAS.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KAS.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KAS.nc
# Dataset : IEA_PVPS-KAR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KAR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KAR.nc
# Dataset : IEA_PVPS-KAO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KAO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KAO.nc
# Dataset : IEA_PVPS-KAA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-KAA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-KAA.nc
# Dataset : IEA_PVPS-JOR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-JOR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-JOR.nc
# Dataset : IEA_PVPS-IZA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-IZA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-IZA.nc
# Dataset : IEA_PVPS-ISL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ISL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ISL.nc
# Dataset : IEA_PVPS-ISH.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ISH.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ISH.nc
# Dataset : IEA_PVPS-HYD.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-HYD.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-HYD.nc
# Dataset : IEA_PVPS-HOW.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-HOW.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-HOW.nc
# Dataset : IEA_PVPS-HAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-HAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-HAN.nc
# Dataset : IEA_PVPS-GUR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GUR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GUR.nc
# Dataset : IEA_PVPS-GOO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GOO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GOO.nc
# Dataset : IEA_PVPS-GOL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GOL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GOL.nc
# Dataset : IEA_PVPS-GOB.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GOB.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GOB.nc
# Dataset : IEA_PVPS-GHA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GHA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GHA.nc
# Dataset : IEA_PVPS-GAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GAN.nc
# Dataset : IEA_PVPS-GAB.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-GAB.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-GAB.nc
# Dataset : IEA_PVPS-FUU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FUU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FUU.nc
# Dataset : IEA_PVPS-FUK.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FUK.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FUK.nc
# Dataset : IEA_PVPS-FOR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FOR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FOR.nc
# Dataset : IEA_PVPS-FOP.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FOP.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FOP.nc
# Dataset : IEA_PVPS-FLO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FLO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FLO.nc
# Dataset : IEA_PVPS-FEN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-FEN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-FEN.nc
# Dataset : IEA_PVPS-ESK.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ESK.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ESK.nc
# Dataset : IEA_PVPS-DWN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DWN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DWN.nc
# Dataset : IEA_PVPS-DUR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DUR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DUR.nc
# Dataset : IEA_PVPS-DLA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DLA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DLA.nc
# Dataset : IEA_PVPS-DES.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DES.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DES.nc
# Dataset : IEA_PVPS-DEA.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DEA.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DEA.nc
# Dataset : IEA_PVPS-DAR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DAR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DAR.nc
# Dataset : IEA_PVPS-DAN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-DAN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-DAN.nc
# Dataset : IEA_PVPS-CON.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CON.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CON.nc
# Dataset : IEA_PVPS-COC.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-COC.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-COC.nc
# Dataset : IEA_PVPS-CHO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CHO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CHO.nc
# Dataset : IEA_PVPS-CHL.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CHL.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CHL.nc
# Dataset : IEA_PVPS-CHI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CHI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CHI.nc
# Dataset : IEA_PVPS-CHB.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CHB.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CHB.nc
# Dataset : IEA_PVPS-CEN.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CEN.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CEN.nc
# Dataset : IEA_PVPS-CEH.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CEH.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CEH.nc
# Dataset : IEA_PVPS-CAR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CAR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CAR.nc
# Dataset : IEA_PVPS-CAI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CAI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CAI.nc
# Dataset : IEA_PVPS-CAH.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CAH.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CAH.nc
# Dataset : IEA_PVPS-CAC.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CAC.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CAC.nc
# Dataset : IEA_PVPS-CAB.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-CAB.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-CAB.nc
# Dataset : IEA_PVPS-BOU.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-BOU.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-BOU.nc
# Dataset : IEA_PVPS-BON.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-BON.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-BON.nc
# Dataset : IEA_PVPS-BLO.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-BLO.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-BLO.nc
# Dataset : IEA_PVPS-BAH.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-BAH.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-BAH.nc
# Dataset : IEA_PVPS-BAC.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-BAC.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-BAC.nc
# Dataset : IEA_PVPS-ARI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ARI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ARI.nc
# Dataset : IEA_PVPS-ALI.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ALI.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ALI.nc
# Dataset : IEA_PVPS-ALE.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ALE.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ALE.nc
# Dataset : IEA_PVPS-ADR.nc
# Download URL http://tds.webservice-energy.org/thredds/fileServer/iea-pvps/IEA_PVPS-ADR.nc
# ODAP URL http://tds.webservice-energy.org/thredds/dodsC/iea-pvps/IEA_PVPS-ADR.nc
