# %%
from src import nx_hif
import xgi

G = nx_hif.read_hif("data/email-enron.json")
H = xgi.from_bipartite_graph(G)
H = H.cleanup()
xgi.draw(H)
# Out:
# (<Axes: >,
#  (<matplotlib.collections.PathCollection at 0x7fcf0c16c890>,
# ...
#   <matplotlib.collections.PatchCollection at 0x7fcf195b14f0>))
