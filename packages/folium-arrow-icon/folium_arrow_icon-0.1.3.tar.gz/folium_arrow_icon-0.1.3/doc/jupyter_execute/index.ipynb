# %% [markdown]
# # Simple arrow (vector/quiver) icon for folium
#
# This package provides simple arrow (vector/quiver) icon for the [folium](https://pypi.org/project/folium/) package.
#
# The arrow (vector/quiver) icon is independent of zoom level, its size does not change as zoom level changes.
# It is useful for displaying vector field.
#
# You can install `folium-arrow-icon` from PyPI:
#
# ```shell
# pip install folium-arrow-icon
# ```
#
# This packages is released under MIT licence.
#
# See [](#sample-code) for example.

# %% [markdown]
# ## Module contents
#
# ```{eval-rst}
# .. automodule:: folium_arrow_icon
#    :members:
#    :undoc-members:
#    :show-inheritance:
# ```

# %% [markdown]
# ## Sample Code

# %%
import math

import folium
from folium_arrow_icon import ArrowIcon

# %% [markdown]
# ### By length and angle

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, 0)
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, math.pi / 2, color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e99bfd47d7acd53fee92e042b2410093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e99bfd47d7acd53fee92e042b2410093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e99bfd47d7acd53fee92e042b2410093 = L.map(
#                 &quot;map_e99bfd47d7acd53fee92e042b2410093&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_833402ce46767e90b68bee541f806354 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_833402ce46767e90b68bee541f806354.addTo(map_e99bfd47d7acd53fee92e042b2410093);
#
#
#             var marker_b728e86eefd2995b18dffdecccdaf936 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_e99bfd47d7acd53fee92e042b2410093);
#
#
#             var div_icon_832bd90bc1512ae89a3f699a6e2dfec1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 21 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-90.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [21, 120]});
#             marker_b728e86eefd2995b18dffdecccdaf936.setIcon(div_icon_832bd90bc1512ae89a3f699a6e2dfec1);
#
#
#             var marker_59fc329313d16d404f418ed3b5c3b0d7 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_e99bfd47d7acd53fee92e042b2410093);
#
#
#             var div_icon_3d69f3a35d1880d2c2d79fa37f0f73d4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 20\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 20]});
#             marker_59fc329313d16d404f418ed3b5c3b0d7.setIcon(div_icon_3d69f3a35d1880d2c2d79fa37f0f73d4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### By components of latitude and longitude direction

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((100, 50))
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((-50, 100), color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dd030a036a246e034d1e9cff4599a27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dd030a036a246e034d1e9cff4599a27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1dd030a036a246e034d1e9cff4599a27 = L.map(
#                 &quot;map_1dd030a036a246e034d1e9cff4599a27&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50f46bcc58c3560bdab5d0d28c74dc98 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_50f46bcc58c3560bdab5d0d28c74dc98.addTo(map_1dd030a036a246e034d1e9cff4599a27);
#
#
#             var marker_f538cf176f916cd77bc87193c149d8b4 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_1dd030a036a246e034d1e9cff4599a27);
#
#
#             var div_icon_85c64fce5bc676230065c7e62afc8778 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 71 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-63.43494882292201 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [71, 120]});
#             marker_f538cf176f916cd77bc87193c149d8b4.setIcon(div_icon_85c64fce5bc676230065c7e62afc8778);
#
#
#             var marker_cf91eb19e122ddcc927b8ee334a788b1 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_1dd030a036a246e034d1e9cff4599a27);
#
#
#             var div_icon_417ad396618a00fcb68bc147a4ff7b26 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 71\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(26.565051177077994 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 71]});
#             marker_cf91eb19e122ddcc927b8ee334a788b1.setIcon(div_icon_417ad396618a00fcb68bc147a4ff7b26);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Variation of anchor

# %%
from folium_arrow_icon import ArrowIconHead, ArrowIconBody

# %%
def marker(i: int, anchor: str, delta: float) -> folium.Marker:
    lat, lng = 40.78322, -73.96551
    return folium.Marker(
        # shif by (0.001 * i, delta) from (40.78322, -73.96551)
        [lat + 0.001 * i, lng + delta],
        icon=ArrowIcon(
            # wavy visualization
            150 + 50 * math.sin(i * math.pi / 20),
            math.pi / 2,
            # rainbowing by css property "hsl"
            color=f"hsl({i * 10}deg, 100%, 50%)",
            # show border of vector
            border_color="black",
            border_width=1,
            # big head
            head=ArrowIconHead(
                width=12,
                length=20
            ),
            # thin body relative to head
            body=ArrowIconBody(
                width=3
            ),
            # anchor is variable
            anchor=anchor
        )
    )

# %%
m = folium.Map(
    location=[40.78322 + 0.015, -73.96551 + 0.035],
    zoom_start=14,
    tiles='Cartodb Positron'
)

for i in range(36):
    # The left is anchor at 'tail' (default)
    marker(i, anchor="tail", delta=0.0).add_to(m)

    # The left is anchor at 'haed'
    marker(i, anchor="head", delta=0.04).add_to(m)

    # The left is anchor at 'mid'
    marker(i, anchor="mid", delta=0.06).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e753f2354bb2b3232e0462caccae43b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e753f2354bb2b3232e0462caccae43b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e753f2354bb2b3232e0462caccae43b = L.map(
#                 &quot;map_2e753f2354bb2b3232e0462caccae43b&quot;,
#                 {
#                     center: [40.79822, -73.93051],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_318cea777aaf6a2635c756985c476436 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_318cea777aaf6a2635c756985c476436.addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var marker_6f3eab742be9a6797c29fd16761a4853 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var div_icon_78eba709931c60c37168e4e0c8f4d1b4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [190, 40]});
#             marker_6f3eab742be9a6797c29fd16761a4853.setIcon(div_icon_78eba709931c60c37168e4e0c8f4d1b4);
#
#
#             var marker_4ff031faf0dafbef188e480844aceaef = L.marker(
#                 [40.78322, -73.92550999999999],
#                 {}
#             ).addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var div_icon_9066db4281f56904308b6ff5133dc3cb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [170.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_4ff031faf0dafbef188e480844aceaef.setIcon(div_icon_9066db4281f56904308b6ff5133dc3cb);
#
#
#             var marker_51d5ec1ed8830566cbac515da650c88b = L.marker(
#                 [40.78322, -73.90550999999999],
#                 {}
#             ).addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var div_icon_ef47fee8ba3746f53831722ead577bb4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [95.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_51d5ec1ed8830566cbac515da650c88b.setIcon(div_icon_ef47fee8ba3746f53831722ead577bb4);
#
#
#             var marker_31093d7d372bd2da99d5184768230d15 = L.marker(
#                 [40.78422, -73.96551],
#                 {}
#             ).addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var div_icon_7c17c36a53a652ae9f14396086717d7e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 198 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(10deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 137.8217 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [198, 40]});
#             marker_31093d7d372bd2da99d5184768230d15.setIcon(div_icon_7c17c36a53a652ae9f14396086717d7e);
#
#
#             var marker_3a524dd672786460bf956a2cb5d3d01b = L.marker(
#                 [40.78422, -73.92550999999999],
#                 {}
#             ).addTo(map_2e753f2354bb2b3232e0462caccae43b);
#
#
#             var div_icon_e00d52a8affd083eaf2e4e85da06f1c3 = L.divIcon({&quot;classNam

# %% [markdown]
# ## Indices and tables
#
# * {ref}`genindex`
# * {ref}`modindex`
# * {ref}`search`
