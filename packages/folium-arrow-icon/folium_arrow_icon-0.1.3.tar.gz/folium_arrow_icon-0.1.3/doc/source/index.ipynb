# %% [markdown]
# # Simple arrow (vector/quiver) icon for folium
#
# This package provides simple arrow (vector/quiver) icon for the [folium](https://pypi.org/project/folium/) package.
#
# The arrow (vector/quiver) icon is independent of zoom level, its size does not change as zoom level changes.
# It is useful for displaying vector field.
#
# You can install `folium-arrow-icon` from PyPI:
#
# ```shell
# pip install folium-arrow-icon
# ```
#
# This packages is released under MIT licence.
#
# See [](#sample-code) for example.

# %% [markdown]
# ## Module contents
#
# ```{eval-rst}
# .. automodule:: folium_arrow_icon
#    :members:
#    :undoc-members:
#    :show-inheritance:
# ```

# %% [markdown]
# ## Sample Code

# %%
import math

import folium
from folium_arrow_icon import ArrowIcon

# %% [markdown]
# ### By length and angle

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, 0)
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, math.pi / 2, color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddfba2d60b85ec5ba93ed31aaf23ab6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddfba2d60b85ec5ba93ed31aaf23ab6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddfba2d60b85ec5ba93ed31aaf23ab6a = L.map(
#                 &quot;map_ddfba2d60b85ec5ba93ed31aaf23ab6a&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bc94f027231b9bcf344ad213ffef33d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1bc94f027231b9bcf344ad213ffef33d.addTo(map_ddfba2d60b85ec5ba93ed31aaf23ab6a);
#
#
#             var marker_dc263540f3ab74d1872c12db884eb3e9 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_ddfba2d60b85ec5ba93ed31aaf23ab6a);
#
#
#             var div_icon_478bbd9c1e3b785b42d3be85d588a5ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 21 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-90.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [21, 120]});
#             marker_dc263540f3ab74d1872c12db884eb3e9.setIcon(div_icon_478bbd9c1e3b785b42d3be85d588a5ad);
#
#
#             var marker_e293d04d4e99ec458ecda2f6389496a8 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_ddfba2d60b85ec5ba93ed31aaf23ab6a);
#
#
#             var div_icon_d7aadc1861762fa8071ef107aa34ddcf = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 20\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 20]});
#             marker_e293d04d4e99ec458ecda2f6389496a8.setIcon(div_icon_d7aadc1861762fa8071ef107aa34ddcf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### By components of latitude and longitude direction

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((100, 50))
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((-50, 100), color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cea5ee6ddd1cf6d7fa617eca0abb1e9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cea5ee6ddd1cf6d7fa617eca0abb1e9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cea5ee6ddd1cf6d7fa617eca0abb1e9d = L.map(
#                 &quot;map_cea5ee6ddd1cf6d7fa617eca0abb1e9d&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d48e58c71ddf05b46507f404b7bda4e5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d48e58c71ddf05b46507f404b7bda4e5.addTo(map_cea5ee6ddd1cf6d7fa617eca0abb1e9d);
#
#
#             var marker_c8fc4ebef1372982512e99715b67e99b = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_cea5ee6ddd1cf6d7fa617eca0abb1e9d);
#
#
#             var div_icon_1746e09a8b8af32a1da888702a2972a8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 71 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-63.43494882292201 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [71, 120]});
#             marker_c8fc4ebef1372982512e99715b67e99b.setIcon(div_icon_1746e09a8b8af32a1da888702a2972a8);
#
#
#             var marker_f82211477ba0c56b94024172fc230337 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_cea5ee6ddd1cf6d7fa617eca0abb1e9d);
#
#
#             var div_icon_462745bc3854c64dd1ce706f40dcf10c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 71\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(26.565051177077994 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 71]});
#             marker_f82211477ba0c56b94024172fc230337.setIcon(div_icon_462745bc3854c64dd1ce706f40dcf10c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Variation of anchor

# %%
from folium_arrow_icon import ArrowIconHead, ArrowIconBody

# %%
def marker(i: int, anchor: str, delta: float) -> folium.Marker:
    lat, lng = 40.78322, -73.96551
    return folium.Marker(
        # shif by (0.001 * i, delta) from (40.78322, -73.96551)
        [lat + 0.001 * i, lng + delta],
        icon=ArrowIcon(
            # wavy visualization
            150 + 50 * math.sin(i * math.pi / 20),
            math.pi / 2,
            # rainbowing by css property "hsl"
            color=f"hsl({i * 10}deg, 100%, 50%)",
            # show border of vector
            border_color="black",
            border_width=1,
            # big head
            head=ArrowIconHead(
                width=12,
                length=20
            ),
            # thin body relative to head
            body=ArrowIconBody(
                width=3
            ),
            # anchor is variable
            anchor=anchor
        )
    )

# %%
m = folium.Map(
    location=[40.78322 + 0.015, -73.96551 + 0.035],
    zoom_start=14,
    tiles='Cartodb Positron'
)

for i in range(36):
    # The left is anchor at 'tail' (default)
    marker(i, anchor="tail", delta=0.0).add_to(m)

    # The left is anchor at 'haed'
    marker(i, anchor="head", delta=0.04).add_to(m)

    # The left is anchor at 'mid'
    marker(i, anchor="mid", delta=0.06).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5e784ab143173e707f746ec5135fc4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5e784ab143173e707f746ec5135fc4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5e784ab143173e707f746ec5135fc4d = L.map(
#                 &quot;map_c5e784ab143173e707f746ec5135fc4d&quot;,
#                 {
#                     center: [40.79822, -73.93051],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42613c683c0970a740659f34a7188cee = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_42613c683c0970a740659f34a7188cee.addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var marker_99020ffb75354f25d8b23a33b25a3976 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var div_icon_7a487680a4dfed0185d6e95da34f5277 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [190, 40]});
#             marker_99020ffb75354f25d8b23a33b25a3976.setIcon(div_icon_7a487680a4dfed0185d6e95da34f5277);
#
#
#             var marker_a37e0f0af40b1d6cd7a7f2acfc5d3b46 = L.marker(
#                 [40.78322, -73.92550999999999],
#                 {}
#             ).addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var div_icon_4d3e19c59f71618fc5851b80eebd9411 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [170.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_a37e0f0af40b1d6cd7a7f2acfc5d3b46.setIcon(div_icon_4d3e19c59f71618fc5851b80eebd9411);
#
#
#             var marker_708be584c911990e50efbe58e95ca408 = L.marker(
#                 [40.78322, -73.90550999999999],
#                 {}
#             ).addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var div_icon_72d5ba3de4228625ee04cbb6aa12a26e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [95.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_708be584c911990e50efbe58e95ca408.setIcon(div_icon_72d5ba3de4228625ee04cbb6aa12a26e);
#
#
#             var marker_4ae9f6075782263b9f17437915c2149f = L.marker(
#                 [40.78422, -73.96551],
#                 {}
#             ).addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var div_icon_9a5ba858497bde1549b49a06a8334c28 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 198 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(10deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 137.8217 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [198, 40]});
#             marker_4ae9f6075782263b9f17437915c2149f.setIcon(div_icon_9a5ba858497bde1549b49a06a8334c28);
#
#
#             var marker_6ab9f02d47aa2531bcd85c32273e6dab = L.marker(
#                 [40.78422, -73.92550999999999],
#                 {}
#             ).addTo(map_c5e784ab143173e707f746ec5135fc4d);
#
#
#             var div_icon_919a02f6e1ca62b46605cedcbb606a80 = L.divIcon({&quot;classNam

# %% [markdown]
# ## Indices and tables
#
# * {ref}`genindex`
# * {ref}`modindex`
# * {ref}`search`
